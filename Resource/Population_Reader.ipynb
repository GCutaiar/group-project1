# %%
import pandas as pd
import os

# %%
file = 'Population_Data.csv'
pop_read = pd.read_csv(file)
pop_read
# Out:
#                   County     2009     2010     2011     2012     2013  \
# 0         Alameda County  1491482  1513043  1530998  1554138  1580247
# 1       El Dorado County   178447   181133   180918   180578   181497
# 2            Kern County   807407   841072   848140   853963   862557
# 3     Los Angeles County  9848011  9822433  9876727  9938436  9998105
# 4          Merced County   245321   256732   259333   260971   262198
# 5            Napa County   134650   136808   137750   138625   139706
# 6          Orange County  3026786  3016559  3050867  3080419  3108009
# 7      Sacramento County  1400949  1421414  1433739  1445078  1457750
# 8       San Diego County  3053793  3103306  3137372  3175201  3211248
# 9       San Mateo County   718989   719725   728404   739427   749013
# 10  Santa Barbara County   407057   424235   425481   429825   434823
# 11         Sierra County     3191     3221     3099     3067     3029
# ...
